# %% [markdown]
# <a href="https://colab.research.google.com/github/advanced-computing/alexa_giulio_rep/blob/main/alexa%26giulio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pip install kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
##import kagglehub

# %%
#path = kagglehub.dataset_download("asaniczka/top-spotify-songs-in-73-countries-daily-updated")
# Out:
# Resuming download from 7340032 bytes (131187350 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/asaniczka/top-spotify-songs-in-73-countries-daily-updated?dataset_version_number=500 (7340032/138527382) bytes left.
#  14%|█▎        | 18.0M/132M [01:20<13:50, 144kB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 path = kagglehub.dataset_download("asaniczka/top-spotify-songs-in-73-countries-daily-updated")
#
# File c:\Users\gtrom\Advanced Computing\alexa_giulio_rep\.venv\Lib\site-packages\kagglehub\datasets.py:34, in dataset_download(handle, path, force_download)
#      32 h = parse_dataset_handle(handle)
#      33 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 34 return registry.dataset_resolver(h, path, force_download=force_download)
#
# ...

# %%
##print(path)
# Out:
# /root/.cache/kagglehub/datasets/asaniczka/top-spotify-songs-in-73-countries-daily-updated/versions/489

# %%
#import os

# %%
#files = os.listdir(path)

# %%
#print(files)
# Out:
# ['universal_top_spotify_songs.csv']

# %%
#import pandas as pd

# %%
#file_path = os.path.join("/root/.cache/kagglehub/datasets/asaniczka/top-spotify-songs-in-73-countries-daily-updated/versions/489", "universal_top_spotify_songs.csv")

# %%
#data = pd.read_csv(file_path)

# %%
#print(data.head())
# Out:
#                spotify_id                name                artists  \
# 0  2plbrEY59IikOBgBGLjaoe    Die With A Smile  Lady Gaga, Bruno Mars
# 1  3sK8wGT43QFpWrvNQsrQya                DtMF              Bad Bunny
# 2  4wJ5Qq0jBN4ajy7ouZIV1c                APT.       ROSÉ, Bruno Mars
# 3  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER          Billie Eilish
# 4  5ZLUm9eab8y3tqQ1OhQSHI         Abracadabra              Lady Gaga
#
#    daily_rank  daily_movement  weekly_movement country snapshot_date  \
# 0           1               0                0     NaN    2025-02-05
# 1           2               0                0     NaN    2025-02-05
# 2           3               0                0     NaN    2025-02-05
# 3           4               0                1     NaN    2025-02-05
# 4           5               3               45     NaN    2025-02-05
#
#    popularity  is_explicit  ...  key loudness mode  speechiness  acousticness  \
# ...

# %%
#as a csv
#df = pd.read_csv("/content/universal_top_spotify_songs 2.csv", quotechar='"')

# %%
#df
# Out:
#                      spotify_id                               name  \
# 0        2plbrEY59IikOBgBGLjaoe                   Die With A Smile
# 1        3sK8wGT43QFpWrvNQsrQya                               DtMF
# 2        4wJ5Qq0jBN4ajy7ouZIV1c                               APT.
# 3        6dOtVTDdiauQNBQEDOtlAB                 BIRDS OF A FEATHER
# 4        5ZLUm9eab8y3tqQ1OhQSHI                        Abracadabra
# ...                         ...                                ...
# 1685089  0AYt6NMyyLd0rLuvr0UkMH          Slime You Out (feat. SZA)
# 1685090  2Gk6fi0dqt91NKvlzGsmm7  SAY MY GRACE (feat. Travis Scott)
# 1685091  26b3oVLrRUaaybJulow9kz                             People
# 1685092  5ydjxBSUIDn26MFzU3asP4                         Rainy Days
# 1685093  59NraMJsLaMCVtwXTSia8i                              Prada
#
#                              artists  daily_rank  daily_movement  \
# 0              Lady Gaga, Bruno Mars           1               0
# ...
